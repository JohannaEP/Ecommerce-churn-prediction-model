# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
# Proyecto: **E-commerce Churn Prediction Model**
#
# Este notebook contiene el análisis exploratorio inicial del dataset.

# %%
# 📌 1. Importación de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 5)

# %%
# 📌 2. Carga del dataset
# Reemplazar 'data.csv' por el nombre real del archivo
df = pd.read_csv("../data/data.csv")

df.head()

# %%
# Información general del dataset
df.info()

# %%
# Estadísticas descriptivas
df.describe()

# %%
# 📌 3. Revisión de valores faltantes
df.isnull().sum()

# %%
# 📌 4. Distribución de variables numéricas
df.hist(bins=30, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
# 📌 5. Matriz de correlación
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Matriz de correlación")
plt.show()

# %%
# 📌 6. Análisis de variables clave (ejemplos)
# Ajustar según las columnas reales del dataset

# sns.boxplot(x=df["purchase_frequency"])
# sns.boxplot(x=df["avg_order_value"])
# sns.boxplot(x=df["days_since_last_purchase"])

# %%
# 📌 7. Guardar dataset limpio (cuando esté listo)
# df.to_csv("../data/data_clean.csv", index=False)
